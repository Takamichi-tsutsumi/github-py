# %% [markdown]
# constraints
# - age < 1000 days
# - Language JavaScript, TypeScript, CoffeeScript

# %%
import os
import requests, json, re, pickle
import pandas as pd
import networkx as nx
from datetime import datetime as dt
import matplotlib.pyplot as plt
import itertools
import functools
from collections import Counter

# %%
API_ROOT = 'https://api.github.com'
API_TOKEN = '6e7fe2b9d8c6da31a832de88eb69922e63c04f9b'
USER = 'Takamichi-tsutsumi'


class NoRepositoryError(Exception):
    pass


def str2dt(tstr):
    return dt.strptime(tstr, '%Y-%m-%dT%H:%M:%SZ')


def api_get(url):
    """
    @args: url
    $return: dict res, int status
    """
    global API_TOKEN, USER
    res = requests.get(url, auth=(USER, API_TOKEN))
    return res.json(), res.status_code


def rate_limit():
    global API_ROOT
    res, _ = api_get(API_ROOT + '/rate_limit')
    return res["resources"]["core"]["remaining"]


def get_repo(repo):
    """repo have to be shape of 'owner/name' """
    repo_pattern = re.compile('[a-zA-Z0-9-]+\/[a-zA-Z0-9-]+$')
    m = repo_pattern.match(repo)
    assert m.group() == repo
    global API_ROOT
    url = API_ROOT + '/repos/' + repo
    res, status  = api_get(url)
    if status == 404:
        raise NoRepositoryError("Repository not found: " + repo)
    return res


def basic_data_of(repo):
    repo_res = get_repo(repo)
    data = {}
    data["repository"] = repo_res["full_name"]
    data["owner_name"] = repo_res["owner"]["login"]
    data["owner_type"] = repo_res["owner"]["type"]
    data["firm_involvement"] = 0 if data["owner_type"] == "User" else 1
    data["is_fork"] = repo_res["fork"]
    data["size"] = repo_res["size"]
    data["language"] = repo_res["language"]
    data["forks"] = repo_res["forks"]
    data["watchers"] = repo_res["watchers"]
    data["created_at"] = repo_res["created_at"]
    data["pushed_at"] = repo_res["pushed_at"]
    data["age (days)"] = (str2dt(data["pushed_at"]) - str2dt(data["created_at"])).days
    return data


def get_contributors_of(repo, per_page=100, page=1):
    url = API_ROOT + '/repos/' + repo + '/contributors?page=' + str(page) + '&per_page=' + str(per_page)
    print("Start fetching contributors of "+repo)
    res, status = api_get(url)
    if status == 200:
        return res
    else:
        raise NoRepositoryError


def repo_url_to_repo(url):
    tokens = url.split("/")
    l = len(tokens)
    return tokens[l-2] + "/" + tokens[l-1]


def is_contributor_of(repo, user):
    n = 100
    i = 1
    all_contributors = []
    while n == 100:
        contributors = get_contributors_of(repo, per_page=100, page=i)
        if user in [c["login"] for c in contributors]:
            return True
        n = len(contributors)
        i += 1
    return False


def repos_user_contributed_to(user, repo):
    i = 1
    n = 100
    all_repos = []
    while n == 100:
        issues_url = API_ROOT + '/search/issues?q=type:pr+author:' + user + '&per_page=100/page=' + str(i)
        res, status = api_get(issues_url)

        if status != 200:
            return []
        else:
            repos = set([repo_url_to_repo(pr['repository_url']) for pr in res["items"]])
            if repo in repos:
                repos.remove(repo)
            all_repos.extend([r for r in list(repos) if is_contributor_of(r, user)])
        n = len(res)
        i += 1
    return all_repos


# Functions to implement graph
def has_connection(cx, cy):
    link = 0
    for i, j in itertools.product(cx["projects"], cy["projects"]):
        if i == j: link += 1;
    return link


def link_of(contributors):
    links = []
    for cx, cy in itertools.combinations(contributors, 2):
        if has_connection(cx, cy) != 0:
            links.append((cx["name"], cy["name"]))
    return links


def graph_of_contributors(cs):
    labels = [c["name"] for c in cs]
    links = link_of(cs)
    G = nx.Graph()
    G.add_nodes_from(labels)
    G.add_edges_from(links)
    return G


# Functions to calculate network characteristics
def cohesion_and_degree_centrality(users):
    count = 0
    for x, y in itertools.combinations(users, 2):
        print(x["name"], y["name"])
        for p in x["projects"]:
            if p in y["projects"]:
                print(p)
                count += 1
    print(count)
    return count / (len(users) * (len(users)-1))
    

def degree_centralities(graph):
    return graph.degree()

def contributors(repo):
    data = []
    n = 100
    i = 1
    while n == 100:
        contributors = get_contributors_of(repo, per_page=100, page=i)
        n = len(contributors)
        i += 1
        for c in contributors:
            user = {
                "id": c["id"],
                "name": c["login"],
                "contributions": c["contributions"]
            }
            projects = repos_user_contributed_to(c["login"], repo)
            user["projects"] = projects
            data.append(user)
    return data


def commit_count(users):
        return functools.reduce(lambda x, y: x + y["contributions"], users, 0)

    
def save_to_csv(data, filename):
    df = pd.DataFrame(data)
    df.to_csv(filename)


def save_contributors(contributors, repo_name):
    df = pd.DataFrame(contributors)
    df.to_csv(os.path.join('contributors', repo_name.replace('/', '_') + '.csv'))


def get_data(repo):
    data = {}
    print("Start fetching repository data...")
    data = basic_data_of(repo)
    print("Successfully fetched repository data!")
    print("Start fetching contributors data...")
    c = contributors(repo)
    save_contributors(c, repo)
    print("Successfully fetched contributors data!")
    data["commits"] = commit_count(c)
    print("Calculate internal cohesion")
    data["manager"] = c[0]["name"]
    data["internal cohesion"] = cohesion(c)
    graph = graph_of_contributors(c)
    data["degree centrality"] = degree_centralities(graph)[data["manager"]]
    return data

# %%
repos = ['Takamichi-tsutsumi/onocolo-client', 'mattn/goveralls']
repo_data = []
for r in repos:
    repo_data.append(get_data(r))
# Out:
# Start fetching repository data...
# Successfully fetched repository data!
# Start fetching contributors data...
# Start fetching contributors of Takamichi-tsutsumi/onocolo-client
# Start fetching contributors of Takamichi-tsutsumi/onocolo-client
# Start fetching contributors of akotani/letel-web
# Start fetching contributors of akotani/letel-rails
# Start fetching contributors of Takamichi-tsutsumi/Meeeal
# Start fetching contributors of akotani/letel-font
# Start fetching contributors of HiroNonoyama/tsurusenishiguchi_dentalClinic
# Start fetching contributors of Takamichi-tsutsumi/ChatStormingServerAPI
# Start fetching contributors of Takamichi-tsutsumi/onocolo-client
# Start fetching contributors of HiroNonoyama/SecretaryBot
# Start fetching contributors of HiroNonoyama/tsurusenishiguchi_dentalClinic
# Start fetching contributors of Takamichi-tsutsumi/Idobata.poli
# Start fetching contributors of Takamichi-tsutsumi/hacker-wars
# Start fetching contributors of Takamichi-tsutsumi/onocolo-client
# Start fetching contributors of HiroNonoyama/SecretaryBot
# Start fetching contributors of HiroNonoyama/ReduxSimpleStarter_4
# Start fetching contributors of HiroNonoyama/TaskManagestBot
# Start fetching contributors of Takamichi-tsutsumi/ChatStorming
# Start fetching contributors of HiroNonoyama/tsurusenishiguchi_dentalClinic
# Start fetching contributors of HiroNonoyama/training
# Successfully fetched contributors data!
# Start fetching repository data...
# Successfully fetched repository data!
# Start fetching contributors data...
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of johnathanhowell/autobuffer
# Start fetching contributors of mackerelio/go-check-plugins
# Start fetching contributors of moznion/linenotcat
# Start fetching contributors of motemen/gofind
# Start fetching contributors of tokuhirom/Caroline
# Start fetching contributors of tkengo/highway
# Start fetching contributors of vim/vim
# Start fetching contributors of Code-Hex/Neo-cowsay
# Start fetching contributors of mattn/go-oci8
# Start fetching contributors of olekukonko/tablewriter
# Start fetching contributors of simeji/jid
# Start fetching contributors of mruby/mruby
# Start fetching contributors of davecheney/httpstat
# Start fetching contributors of rcodetools/rcodetools
# Start fetching contributors of vim-jp/vim-jp.github.io
# Start fetching contributors of junegunn/vim-plug
# Start fetching contributors of svent/sift
# Start fetching contributors of Code-Hex/battery
# Start fetching contributors of google/gops
# Start fetching contributors of ctrlpvim/ctrlp.vim
# Start fetching contributors of tokuhirom/p5-xml-feed-deduper
# Start fetching contributors of pivotal-energy-solutions/django-datatable-view
# Start fetching contributors of dabapps/django-private-views
# Start fetching contributors of crucialfelix/django-ajax-selects
# Start fetching contributors of bradleyg/django-s3direct
# Start fetching contributors of crakjie/landing-page-hugo
# Start fetching contributors of Stouts/Stouts.mongodb
# Start fetching contributors of jmcvetta/neoism
# Start fetching contributors of Stouts/Stouts.jenkins
# Start fetching contributors of jmcvetta/downtest
# Start fetching contributors of litl/rauth
# Start fetching contributors of jmcvetta/napping
# Start fetching contributors of neo4j-contrib/neo4j-org
# Start fetching contributors of tutorcruncher/django-bootstrap3-datetimepicker
# Start fetching contributors of jmcvetta/cspace
# Start fetching contributors of mediapeers/ansible-role-filebeat
# Start fetching contributors of GitbookIO/go-gitbook-api
# Start fetching contributors of mrlesmithjr/ansible-sensu
# Start fetching contributors of TauLabs/TauLabs
# Start fetching contributors of TobiasBales/PlayuavOSDConfigurator
# Start fetching contributors of dustin/go-humanize
# Start fetching contributors of Xastir/Xastir
# Start fetching contributors of ShikOfTheRa/scarab-osd
# Start fetching contributors of d-ronin/dRonin
# Start fetching contributors of BrainFPV/TauLabs
# Start fetching contributors of hideo55/go-popcount
# Start fetching contributors of mistergone/electoral-charts
# Start fetching contributors of haya14busa/go-vimlparser
# Start fetching contributors of haya14busa/reviewdog
# Start fetching contributors of vim-jp/reading-vimrc
# Start fetching contributors of yudai/gojsondiff
# Start fetching contributors of vim-jp/vital.vim
# Start fetching contributors of mackerelio/mackerel-client-go
# Start fetching contributors of mackerelio/mkr
# Start fetching contributors of haya14busa/gosum
# Start fetching contributors of mackerelio/mackerel-agent
# Start fetching contributors of apexskier/httpauth
# Start fetching contributors of gorilla/schema
# Start fetching contributors of jessevdk/go-flags
# Start fetching contributors of tquach/golang-rest-server
# Start fetching contributors of go-mgo/mgo
# Start fetching contributors of vmihailenco/msgpack
# Start fetching contributors of thestinger/termite
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of avelino/awesome-go
# Start fetching contributors of avelino/awesome-go
# Start fetching contributors of avelino/awesome-go
# Start fetching contributors of avelino/awesome-go
# Start fetching contributors of janmojzis/tinyssh
# Start fetching contributors of kr/pretty
# Start fetching contributors of googlesamples/mugo
# Start fetching contributors of maruel/gohci
# Start fetching contributors of gorilla/context
# Start fetching contributors of luci/python-adb
# Start fetching contributors of lvv/git-prompt
# Start fetching contributors of kr/goven
# Start fetching contributors of golang/gddo
# Start fetching contributors of nsf/tulib
# Start fetching contributors of pfalcon/esp-open-sdk
# Start fetching contributors of kr/text
# Start fetching contributors of spf13/hugo
# Start fetching contributors of go-yaml/yaml
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of kisielk/gotool
# Start fetching contributors of golang/lint
# Start fetching contributors of google/python-adb
# Start fetching contributors of tools/godep
# Start fetching contributors of shurcooL/vcsstate
# Start fetching contributors of blhack/goInternet
# Start fetching contributors of go-phoenix-chandler/talks
# Start fetching contributors of cogger/cogger
# Start fetching contributors of SeanDolphin/horsefeather
# Start fetching contributors of SeanDolphin/bqschema
# Start fetching contributors of brn/closure-deps-resolver
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of gogolfing/dotenv
# Start fetching contributors of AgencyPMG/passport-google-idtoken
# Start fetching contributors of gogolfing/httplog
# Start fetching contributors of AgencyPMG/node-super-config
# Start fetching contributors of gogolfing/dbschema
# Start fetching contributors of AgencyPMG/higherform
# Start fetching contributors of gogolfing/config
# Start fetching contributors of gogolfing/httpmux
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of gogolfing/timequeue
# Start fetching contributors of velour/catbase
# Start fetching contributors of eaburns/T
# Start fetching contributors of gonum/plot
# Start fetching contributors of prometheus/prometheus
# Start fetching contributors of progrium/gh-release
# Start fetching contributors of Chiel92/vim-autoformat
# Start fetching contributors of zvelo/lmdb
# Start fetching contributors of JuliaLang/utf8proc
# Start fetching contributors of Shougo/unite.vim
# Start fetching contributors of Homebrew/homebrew-core
# Start fetching contributors of Homebrew/homebrew-core
# Start fetching contributors of Homebrew/homebrew-core
# Start fetching contributors of Homebrew/homebrew-core
# Start fetching contributors of Homebrew/homebrew-core
# Start fetching contributors of mattn/go-runewidth
# Start fetching contributors of junegunn/fzf
# Start fetching contributors of FredrikAppelros/grunt-coffee-coverage
# Start fetching contributors of vim-airline/vim-airline
# Start fetching contributors of vvakame/typescript-formatter
# Start fetching contributors of spf13/cast
# Start fetching contributors of tmux/tmux
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of smartystreets/goconvey
# Start fetching contributors of vim-syntastic/syntastic
# Start fetching contributors of spf13/viper
# Start fetching contributors of nsqio/nsq
# Start fetching contributors of ap/vim-buftabline
# Start fetching contributors of urfave/cli
# Start fetching contributors of zvelo/msg
# Start fetching contributors of junegunn/go-runewidth
# Start fetching contributors of gdamore/tcell
# Start fetching contributors of pkg/errors
# Start fetching contributors of go-clang/v3.9
# Start fetching contributors of go-clang/bootstrap
# Start fetching contributors of go-clang/v3.7
# Start fetching contributors of go-clang/v3.6
# Start fetching contributors of jessevdk/go-flags
# Start fetching contributors of go-clang/v3.8
# Start fetching contributors of zimmski/go-mutesting
# Start fetching contributors of go-clang/v3.4
# Start fetching contributors of sergi/go-diff
# Start fetching contributors of go-clang/gen
# Start fetching contributors of whitequark/parser
# Start fetching contributors of resque/resque
# Start fetching contributors of backus/rubocop-rspec
# Start fetching contributors of kapost/circuitry
# Start fetching contributors of enova/business_calendar
# Start fetching contributors of aws/aws-codedeploy-agent
# Start fetching contributors of enova/obvious_data
# Start fetching contributors of enova/sidekiq-rate-limiter
# Start fetching contributors of mhfs/sidekiq-failures
# Start fetching contributors of bbatsov/rubocop
# Start fetching contributors of bbatsov/rubocop
# Start fetching contributors of bbatsov/rubocop
# Start fetching contributors of banister/method_source
# Start fetching contributors of pd/figgy
# Start fetching contributors of mgomes/api_auth
# Start fetching contributors of holidays/holidays
# Start fetching contributors of rails/rails
# Start fetching contributors of rails/rails
# Start fetching contributors of rails/rails
# Start fetching contributors of rails/rails
# Start fetching contributors of rails/rails
# Start fetching contributors of mperham/sidekiq
# Start fetching contributors of mperham/sidekiq
# Start fetching contributors of mperham/sidekiq
# Start fetching contributors of mperham/sidekiq
# Start fetching contributors of lemurheavy/coveralls-ruby
# Start fetching contributors of puma/puma
# Start fetching contributors of companygardener/lookup_by
# Start fetching contributors of mschae/trailing_format_plug
# Start fetching contributors of bwthomas/stachio
# Start fetching contributors of netvl/xml-rs
# Start fetching contributors of inconshreveable/log15
# Start fetching contributors of servo/core-foundation-rs
# Start fetching contributors of GiantToast/language-terraform
# Start fetching contributors of gfx-rs/gfx
# Start fetching contributors of kevinswiber/siren
# Start fetching contributors of matthiasnoback/SymfonyDependencyInjectionTest
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of uecode/qpush-bundle
# Start fetching contributors of robertg/rustkit
# Start fetching contributors of graymeta/stow
# Start fetching contributors of guzzle/guzzle-services
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of servo/cocoa-rs
# Start fetching contributors of iron-io/docs
# Start fetching contributors of tomaka/glutin
# Start fetching contributors of iron-io/enterprise
# Start fetching contributors of n-boy/backuper
# Start fetching contributors of avelino/awesome-go
# Start fetching contributors of msoap/shell2telegram
# Start fetching contributors of pkg/errors
# Start fetching contributors of cweill/gotests
# Start fetching contributors of coreos/etcd
# Start fetching contributors of coreos/etcd
# Start fetching contributors of coreos/etcd
# Start fetching contributors of kulshekhar/fungen
# Start fetching contributors of gojuno/minimock
# Start fetching contributors of nats-io/go-nats
# Start fetching contributors of huytd/playgo
# Start fetching contributors of golang/lint
# Start fetching contributors of gchaincl/dotsql
# Start fetching contributors of andmarti1424/sc-im
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of msoap/docker-golang-checks
# Start fetching contributors of syscrusher/golang.tmbundle
# Start fetching contributors of msoap/shell2http
# Start fetching contributors of BurntSushi/goim
# Start fetching contributors of spf13/hugo
# Start fetching contributors of spf13/hugo
# Start fetching contributors of spf13/hugo
# Start fetching contributors of spf13/hugo
# Start fetching contributors of gijsbers/go-pcre
# Start fetching contributors of d4l3k/go-highlight
# Start fetching contributors of krausest/js-framework-benchmark
# Start fetching contributors of aomarks/bridgesim
# Start fetching contributors of d4l3k/messagediff
# Start fetching contributors of cockroachdb/cockroach
# Start fetching contributors of spf13/hugo
# Start fetching contributors of spf13/hugo
# Start fetching contributors of spf13/hugo
# Start fetching contributors of spf13/hugo
# Start fetching contributors of BesMurzik/exp
# Start fetching contributors of pierrre/gotestcover
# Start fetching contributors of src-d/go-git
# Start fetching contributors of alecthomas/gometalinter
# Start fetching contributors of gitinsky/ansible-consul
# Start fetching contributors of inCaller/prometheus_bot
# Start fetching contributors of pkg/errors
# Start fetching contributors of koorchik/Mojolicious-Plugin-ValidateTiny
# Start fetching contributors of tiimgreen/github-cheat-sheet
# Start fetching contributors of tokuhirom/App-scan_prereqs_cpanfile
# Start fetching contributors of powerman/gotestcover
# Start fetching contributors of dagolden/Path-Tiny
# Start fetching contributors of miyagawa/Dist-Milla
# Start fetching contributors of asciidoc/asciidoc
# Start fetching contributors of leejo/cgi-fast
# Start fetching contributors of github/linguist
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of fatih/vim-go
# Start fetching contributors of fatih/vim-go
# Start fetching contributors of gentoo/gentoo
# Start fetching contributors of gentoo/gentoo
# Start fetching contributors of gentoo/gentoo
# Start fetching contributors of benbjohnson/wtf
# Start fetching contributors of gophercon/2016-talks
# Start fetching contributors of boltdb/bolt
# Start fetching contributors of influxdata/influxdb
# Start fetching contributors of drone-plugins/drone-docker
# Start fetching contributors of appleboy/drone-jenkins
# Start fetching contributors of gin-gonic/contrib
# Start fetching contributors of docker/docker.github.io
# Start fetching contributors of docker/docker.github.io
# Start fetching contributors of docker/docker.github.io
# Start fetching contributors of docker/docker.github.io
# Start fetching contributors of sideshow/apns2
# Start fetching contributors of appleboy/drone-scp
# Start fetching contributors of paked/messenger
# Start fetching contributors of appleboy/gorush
# Start fetching contributors of appleboy/drone-telegram
# Start fetching contributors of drone-plugins/drone-slack
# Start fetching contributors of drone/drone-tutorials
# Start fetching contributors of gin-gonic/gin
# Start fetching contributors of appleboy/Shell-Script
# Start fetching contributors of laradock/laradock
# Start fetching contributors of appleboy/drone-line
# Start fetching contributors of appleboy/golang-testing
# Start fetching contributors of AZaugg/newrelic-tools
# Start fetching contributors of couchbase/couchbase-python-client
# Start fetching contributors of fnerdwq/puppet-omd
# Start fetching contributors of Dasister/Source-Query-Class-Python
# Start fetching contributors of leighmaddock/ConiteDB
# Start fetching contributors of naparuba/shinken
# Start fetching contributors of umermansoor/microservices
# Start fetching contributors of melpa/melpa
# Start fetching contributors of melpa/melpa
# Start fetching contributors of melpa/melpa
# Start fetching contributors of melpa/melpa
# Start fetching contributors of melpa/melpa
# Start fetching contributors of daniellawrence/aws-map
# Start fetching contributors of pycontribs/jira
# Start fetching contributors of garbados/orchestrate-sql
# Start fetching contributors of flask-admin/flask-admin
# Start fetching contributors of flask-admin/flask-admin
# Start fetching contributors of daniellawrence/graphitesend
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of jrgp/soldat-pystats
# Start fetching contributors of KimberleyLawrence/babybook
# Start fetching contributors of byteweaver/django-referral
# Start fetching contributors of Microsoft/vsts-tasks
# Start fetching contributors of Microsoft/vsts-tasks
# Start fetching contributors of warner/python-versioneer
# Start fetching contributors of meetecho/janus-gateway
# Start fetching contributors of kpawlik/geojson
# Start fetching contributors of faif/python-patterns
# Start fetching contributors of terencehonles/fusepy
# Start fetching contributors of dsoprea/PySvn
# Start fetching contributors of bernieke/python-magento
# Start fetching contributors of hwdsl2/setup-ipsec-vpn
# Start fetching contributors of DenisCarriere/geonames
# Start fetching contributors of nsqio/nsq
# Start fetching contributors of shelljs/shelljs
# Start fetching contributors of jmandel/smart-on-fhir-installer
# Start fetching contributors of smart-on-fhir/installer-legacy
# Start fetching contributors of linsomniac/python-memcached
# Start fetching contributors of xolox/python-deb-pkg-tools
# Start fetching contributors of dsoprea/GDriveFS
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of dsoprea/go-appengine-logging
# Start fetching contributors of graphql-go/handler
# Start fetching contributors of gorilla/sessions
# Start fetching contributors of Homebrew/homebrew-core
# Start fetching contributors of ef-ctx/hipache-healthcheck-proxy
# Start fetching contributors of alecthomas/gometalinter
# Start fetching contributors of NYTimes/video-transcoding-api
# Start fetching contributors of athrunsun/homebrew-linuxbinary
# Start fetching contributors of tsuru/tsuru
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of travis-ci/gimme
# Start fetching contributors of ef-ctx/tranor
# Start fetching contributors of NYTimes/encoding-wrapper
# Start fetching contributors of ejholmes/slashdeploy
# Start fetching contributors of juliexue/git-undo
# Start fetching contributors of Nosajool/circle-cov
# Start fetching contributors of aws/aws-sdk-go
# Start fetching contributors of rollbar/rollbar-gem
# Start fetching contributors of dvdfu/match-3
# Start fetching contributors of ejholmes/requestid
# Start fetching contributors of remind101/empire
# Start fetching contributors of c9dong/WeSmash
# Start fetching contributors of matthewdu/slack-slam
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of Nosajool/smash-tracker
# Start fetching contributors of ansible/ansibullbot
# Start fetching contributors of ansible/ansible
# Start fetching contributors of ansible/ansible-modules-extras
# Start fetching contributors of ansible/ansible-modules-core
# Start fetching contributors of ansible/prmove
# Start fetching contributors of go-zoo/bone
# Start fetching contributors of rakyll/command
# Start fetching contributors of bakkenbaeck/orbit-api-client
# Start fetching contributors of docker/docker
# Start fetching contributors of docker/docker
# Start fetching contributors of docker/docker
# Start fetching contributors of docker/docker
# Start fetching contributors of docker/docker
# Start fetching contributors of jwilder/docker-gen
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of symfony/symfony
# Start fetching contributors of inlet/CakePHP-LinkedIn
# Start fetching contributors of arcus-io/docker-kibana
# Start fetching contributors of disqus/disqus-php
# Start fetching contributors of fsouza/go-dockerclient
# Start fetching contributors of fsouza/go-dockerclient
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of dbmedialab/goorbitapi
# Start fetching contributors of gentoo/gentoo-portage-rsync-mirror
# Start fetching contributors of rust-lang-nursery/bitflags
# Start fetching contributors of spacemonkeygo/flagfile
# Start fetching contributors of jmesmon/rust-systemd
# Start fetching contributors of yosssi/boltstore
# Start fetching contributors of rust-lang/rust-installer
# Start fetching contributors of bingomanatee/node-dir-diff
# Start fetching contributors of SRI-CSL/PVS
# Start fetching contributors of gentoo/kde
# Start fetching contributors of tpjg/goriakpbc
# Start fetching contributors of dokku/dokku
# Start fetching contributors of dokku/dokku
# Start fetching contributors of dokku/dokku
# Start fetching contributors of gentoo/gentoo
# Start fetching contributors of gentoo/gentoo
# Start fetching contributors of boltdb/bolt
# Start fetching contributors of getlantern/http-proxy
# Start fetching contributors of getlantern/idletiming
# Start fetching contributors of getlantern/sysproxy
# Start fetching contributors of getlantern/smux
# Start fetching contributors of Yawning/obfs4
# Start fetching contributors of xtaci/smux
# Start fetching contributors of getlantern/edgedetect
# Start fetching contributors of getlantern/protected
# Start fetching contributors of getlantern/lanternlib
# Start fetching contributors of getlantern/interceptor
# Start fetching contributors of getlantern/cmux
# Start fetching contributors of getlantern/zenodb
# Start fetching contributors of getlantern/sysproxy-cmd
# Start fetching contributors of getlantern/borda
# Start fetching contributors of getlantern/proxy
# Start fetching contributors of dnsimple/dnsimple-developer
# Start fetching contributors of unixcharles/acme-client
# Start fetching contributors of dnsimple/dnsimple-go
# Start fetching contributors of hashicorp/terraform
# Start fetching contributors of hashicorp/terraform
# Start fetching contributors of hashicorp/terraform
# Start fetching contributors of hashicorp/terraform
# Start fetching contributors of hashicorp/terraform
# Start fetching contributors of weppos/publicsuffix-go
# Start fetching contributors of publicsuffix/list
# Start fetching contributors of dnsimple/dnsimple-ruby
# Start fetching contributors of dnsimple/dnsimple-support
# Start fetching contributors of dnsimple/dnsimple-elixir
# Start fetching contributors of tmilewski/serverless-resources-validation-plugin
# Start fetching contributors of carrot/roots-js-pipeline
# Start fetching contributors of ruby-grape/grape-swagger
# Start fetching contributors of omniauth/omniauth
# Start fetching contributors of tmilewski/dotfiles
# Start fetching contributors of DigitalCitadel/originator
# Start fetching contributors of faunadb/faunadb-ruby
# Start fetching contributors of serverless/serverless
# Start fetching contributors of tmilewski/goenv
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of intridea/omniauth-oauth2
# Start fetching contributors of holman/dotfiles
# Start fetching contributors of intridea/omniauth-github
# Start fetching contributors of carrot/share-button
# Start fetching contributors of static-dev/spike-contentful
# Start fetching contributors of tmilewski/omniauth-github
# Start fetching contributors of carrot/hygienist-middleware
# Start fetching contributors of carrot/roots-contentful
# Start fetching contributors of alexanderjarvis/play-jongo
# Start fetching contributors of iloveponies/training-day
# Start fetching contributors of caskroom/homebrew-cask
# Start fetching contributors of caskroom/homebrew-cask
# Start fetching contributors of caskroom/homebrew-cask
# Start fetching contributors of caskroom/homebrew-cask
# Start fetching contributors of caskroom/homebrew-cask
# Start fetching contributors of go-lang-plugin-org/go-lang-idea-plugin
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of iloveponies/i-am-a-horse-in-the-land-of-booleans
# Start fetching contributors of dustin/gomemcached
# Start fetching contributors of abhi-bit/builder
# Start fetching contributors of mnunberg/couchnode
# Start fetching contributors of couchbase/indexing
# Start fetching contributors of couchbase/go-couchbase
# Start fetching contributors of couchbaselabs/query
# Start fetching contributors of dustin/go-jsonpointer
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of couchbase/manifest
# Start fetching contributors of AMeng/stackdriver
# Start fetching contributors of TheJumpCloud/rsc
# Start fetching contributors of sendgrid/sendgrid-go
# Start fetching contributors of clbanning/x2j
# Start fetching contributors of rsc/rsc
# Start fetching contributors of rmulley/go-fast-sql
# Start fetching contributors of ryanskidmore/GoWork
# Start fetching contributors of cbinsights/goamz
# Start fetching contributors of cbinsights/intercom-go
# Start fetching contributors of mattn/goveralls
# Start fetching contributors of cbinsights/cbi-go
# Start fetching contributors of prh/rules
# Start fetching contributors of skatejs/skatejs
# Start fetching contributors of favclip/golidator
# Start fetching contributors of DefinitelyTyped/DefinitelyTyped
# Start fetching contributors of mjibson/goon
# Start fetching contributors of azu/wzeditor-word-rules-parser
# Start fetching contributors of Microsoft/TypeScript
# Start fetching contributors of Microsoft/TSJS-lib-generator
# Start fetching contributors of SekiguchiKai/JankenServer
# Start fetching contributors of vvakame/typescript-formatter
# Start fetching contributors of vvakame/wzeditor-word-rules-parser
# Start fetching contributors of angular/universal
# Start fetching contributors of skatejs/web-components
# Start fetching contributors of prh/prh
# Start fetching contributors of DefinitelyTyped/dt-review-tool
# Start fetching contributors of angular/preboot
# Start fetching contributors of favclip/ucon
# Successfully fetched contributors data!

# %%
save_to_csv(repo_data, 'repos.csv')

# %%
rate_limit()
# Out:
# 4983

# %%
contributors_onocolo = get_data('Takamichi-tsutsumi/onocolo-client')
# Out:
# Start fetching repository data...
# Successfully fetched repository data!
# Start fetching contributors data...
# Start fetching contributors of Takamichi-tsutsumi/onocolo-client
# Start fetching contributors of akotani/letel-rails
# Start fetching contributors of HiroNonoyama/tsurusenishiguchi_dentalClinic
# Start fetching contributors of akotani/letel-font
# Start fetching contributors of akotani/letel-web
# Start fetching contributors of Takamichi-tsutsumi/Meeeal
# Start fetching contributors of HiroNonoyama/tsurusenishiguchi_dentalClinic
# Start fetching contributors of Takamichi-tsutsumi/ChatStormingServerAPI
# Start fetching contributors of HiroNonoyama/SecretaryBot
# Start fetching contributors of Takamichi-tsutsumi/Idobata.poli
# Start fetching contributors of Takamichi-tsutsumi/hacker-wars
# Start fetching contributors of HiroNonoyama/training
# Start fetching contributors of Takamichi-tsutsumi/ChatStorming
# Start fetching contributors of HiroNonoyama/tsurusenishiguchi_dentalClinic
# Start fetching contributors of HiroNonoyama/ReduxSimpleStarter_4
# Start fetching contributors of HiroNonoyama/SecretaryBot
# Start fetching contributors of HiroNonoyama/TaskManagestBot
# Successfully fetched contributors data!
# Calculate internal cohesion
# Takamichi-tsutsumi KanUchida
# HiroNonoyama/tsurusenishiguchi_dentalClinic
# Takamichi-tsutsumi HiroNonoyama
# HiroNonoyama/tsurusenishiguchi_dentalClinic
# KanUchida HiroNonoyama
# HiroNonoyama/tsurusenishiguchi_dentalClinic
# HiroNonoyama/SecretaryBot
# 4

# %%
def search_repos():
    p = 1
    status = 200
    repos = []
    while 20 >= p and status == 200:
        url = 'https://api.github.com/search/repositories?q=language:javascript+created:>2014-01-01&sort=stars&order=desc&per_page=100&page' + str(p)
        res, status = api_get(url)
        if status == 200:
            repos.extend([r["full_name"] for r in res["items"]])
        p += 1
    return repos

# %%
repos = search_repos()

# %%
repos
# Out:
# ['FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'reactjs/redux',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'angular/material',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'github/fetch',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'juliangarnier/anime',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'chrisaljoudi/uBlock',
#  'sindresorhus/pageres',
#  'buunguyen/octotree',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'Famous/famous',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'mozilla/metrics-graphics',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'shekhargulati/52-technologies-in-2016',
#  'iissnan/hexo-theme-next',
#  'AngularClass/angular2-webpack-starter',
#  'sbstjn/timesheet.js',
#  'karpathy/convnetjs',
#  'huluoyang/freecodecamp.cn',
#  'vladikoff/chromeos-apk',
#  'rethinkdb/horizon',
#  'twitter/twemoji',
#  'Microsoft/ChakraCore',
#  'reactjs/react-redux',
#  'ruanyf/jstraining',
#  'paularmstrong/normalizr',
#  'akveo/blur-admin',
#  'geeeeeeeeek/electronic-wechat',
#  'aFarkas/lazysizes',
#  'JedWatson/react-select',
#  'yelouafi/redux-saga',
#  'Nickersoft/push.js',
#  'facebook/nuclide',
#  'gabrielbull/react-desktop',
#  'metalsmith/metalsmith',
#  'coryhouse/react-slingshot',
#  'ruanyf/es6tutorial',
#  'thejameskyle/itsy-bitsy-data-structures',
#  'OAI/OpenAPI-Specification',
#  'kimmobrunfeldt/progressbar.js',
#  'reactjs/react-router-redux',
#  'jaredreich/notie',
#  'LeaVerou/awesomplete',
#  'reflux/refluxjs',
#  'Laverna/laverna',
#  'auchenberg/volkswagen',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'iissnan/hexo-theme-next',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'julianshapiro/velocity',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'jaywcjlove/awesome-mac',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'rollup/rollup',
#  'facebook/relay',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'hacksalot/HackMyResume',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'iissnan/hexo-theme-next',
#  'AngularClass/angular2-webpack-starter',
#  'sbstjn/timesheet.js',
#  'huluoyang/freecodecamp.cn',
#  'gaearon/react-hot-loader',
#  'vladikoff/chromeos-apk',
#  'twitter/twemoji',
#  'Microsoft/ChakraCore',
#  'reactjs/react-redux',
#  'cyclejs/cyclejs',
#  'ruanyf/jstraining',
#  'plotly/plotly.js',
#  'paularmstrong/normalizr',
#  'geeeeeeeeek/electronic-wechat',
#  'yelouafi/redux-saga',
#  'Nickersoft/push.js',
#  'facebook/nuclide',
#  'gabrielbull/react-desktop',
#  'metalsmith/metalsmith',
#  'coryhouse/react-slingshot',
#  'ruanyf/es6tutorial',
#  'thejameskyle/itsy-bitsy-data-structures',
#  'graphql/graphql-js',
#  'OAI/OpenAPI-Specification',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'FreeCodeCamp/FreeCodeCamp',
#  'facebook/react-native',
#  'nodejs/node',
#  'reactjs/redux',
#  'NARKOZ/hacker-scripts',
#  'Dogfalo/materialize',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'babel/babel',
#  'ReactTraining/react-router',
#  'facebookincubator/create-react-app',
#  'kenwheeler/slick',
#  'facebook/immutable-js',
#  'zenorocha/clipboard.js',
#  'angular/material',
#  't4t5/sweetalert',
#  'bevacqua/dragula',
#  'GitbookIO/gitbook',
#  'serverless/serverless',
#  'Kickball/awesome-selfhosted',
#  'zeit/hyper',
#  'facebook/flux',
#  'ParsePlatform/parse-server',
#  'kriasoft/react-starter-kit',
#  'julianshapiro/velocity',
#  'github/fetch',
#  'jlmakes/scrollreveal',
#  'mxstbr/react-boilerplate',
#  'naptha/tesseract.js',
#  'mzabriskie/axios',
#  'RocketChat/Rocket.Chat',
#  'juliangarnier/anime',
#  'MostlyAdequate/mostly-adequate-guide',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'ampproject/amphtml',
#  'verekia/js-stack-from-scratch',
#  'keen/dashboards',
#  'knsv/mermaid',
#  'gionkunz/chartist-js',
#  'parkjs814/AlgorithmVisualizer',
#  'legomushroom/mojs',
#  'petehunt/webpack-howto',
#  'Selz/plyr',
#  'aurelia/framework',
#  'jiahaog/nativefier',
#  'DrkSephy/es6-cheatsheet',
#  'feross/standard',
#  'yaronn/blessed-contrib',
#  'erikras/react-redux-universal-hot-example',
#  'facebook/draft-js',
#  'Automattic/wp-calypso',
#  'fbsamples/f8app',
#  'ptmt/react-native-macos',
#  'jaywcjlove/awesome-mac',
#  'ruanyf/react-demos',
#  'VincentGarreau/particles.js',
#  'wekan/wekan',
#  'chrisaljoudi/uBlock',
#  'FormidableLabs/webpack-dashboard',
#  'sindresorhus/pageres',
#  'maxwellito/vivus',
#  'buunguyen/octotree',
#  'rollup/rollup',
#  'facebook/relay',
#  'arasatasaygin/is.js',
#  'airbnb/enzyme',
#  'kesenhoo/android-training-course-in-chinese',
#  'oneuijs/You-Dont-Need-jQuery',
#  'hacksalot/HackMyResume',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'alsotang/node-lessons',
#  'gorhill/uBlock',
#  'zeit/next.js',
#  'qrohlf/trianglify',
#  'Matt-Esch/virtual-dom',
#  'chenglou/react-motion',
#  'davezuko/react-redux-starter-kit',
#  'Netflix/falcor',
#  'dthree/cash',
#  'trueadm/inferno',
#  'Famous/famous',
#  'docker/kitematic',
#  'gatsbyjs/gatsby',
#  'purifycss/purifycss',
#  'relax/relax',
#  'gaearon/redux-devtools',
#  'mozilla/metrics-graphics',
#  'thejameskyle/the-super-tiny-compiler',
#  'nosir/cleave.js',
#  'mobxjs/mobx',
#  'Bilibili/flv.js',
#  'Mango/slideout',
#  'developit/preact',
#  'shekhargulati/52-technologies-in-2016',
#  'callemall/material-ui',
#  'nylas/N1',
#  'yarnpkg/yarn',
#  'angular/material',
#  'GitbookIO/gitbook',
#  'kriasoft/react-starter-kit',
#  'github/fetch',
#  'segmentio/nightmare',
#  'mattermost/platform',
#  'git-tips/tips',
#  'jwagner/smartcrop.js',
#  'Flipboard/react-canvas',
#  'legomushroom/mojs',
#  'facebook/draft-js',
#  'ptmt/react-native-macos',
#  'ruanyf/react-demos',
#  'buunguyen/octotree',
#  'arasatasaygin/is.js',
#  'oneuijs/You-Dont-Need-jQuery',
#  'storybooks/react-storybook',
#  'avajs/ava',
#  'Famous/famous',
#  'purifycss/purifycss',
#  'relax/relax',
#  'karpathy/convnetjs',
#  'rethinkdb/horizon',
#  'akveo/blur-admin',
#  'aFarkas/lazysizes',
#  'JedWatson/react-select',
#  'kimmobrunfeldt/progressbar.js',
#  'reactjs/react-router-redux',
#  'jaredreich/notie',
#  'callmecavs/layzr.js',
#  'react-toolbox/react-toolbox',
#  'typicode/hotel',
#  'liabru/matter-js',
#  'js-cookie/js-cookie',
#  'justjavac/awesome-wechat-weapp',
#  'FormidableLabs/radium',
#  'fengyuanchen/cropper',
#  'deepstreamIO/deepstream.io',
#  'gavinkwoe/weapp-ide-crack',
#  'gaearon/react-dnd',
#  'aframevr/aframe',
#  'bvaughn/react-virtualized',
#  'TalAter/UpUp',
#  'sentsin/layer',
#  'gaearon/redux-thunk',
#  'erming/shout',
#  'reapp/reapp',
#  'timuric/Content-generator-sketch-plugin',
#  'callmecavs/bricks.js',
#  'FormidableLabs/victory',
#  'luin/medis',
#  'amfe/lib-flexible',
#  'gaearon/react-transform-boilerplate',
#  'ruanyf/webpack-demos',
#  'henryboldi/felony',
#  'race604/ZhiHuDaily-React-Native',
#  'styled-components/styled-components',
#  'casesandberg/react-color',
#  'Hashnode/mern-starter',
#  'VodkaBears/Vide',
#  'jonathantneal/flexibility',
#  'muicss/mui',
#  'anijs/anijs',
#  'yeoman/generator-webapp',
#  'nfl/react-helmet',
#  'futurice/pepperoni-app-kit',
#  'astoilkov/jsblocks',
#  'arkency/reactjs_koans',
#  'feross/webtorrent-desktop',
#  'michalsnik/aos',
#  'JexCheng/regulex',
#  'lebab/lebab',
#  'Raynos/mercury',
#  'chjj/ttystudio',
#  'ankane/pghero',
#  'stylelint/stylelint',
#  'benhowdle89/grade',
#  'iSimar/HackerNews-React-Native',
#  'googlesamples/md2googleslides',
#  'google/incremental-dom',
#  'reek/anti-adblock-killer',
#  'VodkaBears/Remodal',
#  'nathancahill/Split.js',
#  'felipernb/algorithms.js',
#  'btford/write-good',
#  'aroc/side-comments',
#  'HospitalRun/hospitalrun-frontend',
#  'SlexAxton/css-colorguard',
#  'tholman/intense-images',
#  'formly-js/angular-formly',
#  'google/code-prettify',
#  'jtblin/angular-chart.js',
#  'taobaofed/react-web',
#  'ParsePlatform/parse-dashboard',
#  'iam4x/pokemongo-webspoof',
#  'react-webpack-generators/generator-react-webpack',
#  'th0r/webpack-bundle-analyzer',
#  ...]

# %%
def repos_data(repos):
    data = []
    for r in repos:
        data.append(get_data(r))
    return data

# %%
oss_data = repos_data(repos[:15])
save_to_csv(oss_data, 'oss_data.csv')
# Out:
# Start fetching repository data...
# Successfully fetched repository data!
# Start fetching contributors data...
# Start fetching contributors of FreeCodeCamp/FreeCodeCamp
# Start fetching contributors of FreeCodeCamp/hour-of-code
# Start fetching contributors of FreeCodeCamp/design-style-guide
# Start fetching contributors of QuincyLarson/hyperdev-test
# Start fetching contributors of neveragaindottech/neveragaindottech.github.io
# Start fetching contributors of neveragaindottech/neveragaindottech.github.io
# Start fetching contributors of neveragaindottech/neveragaindottech.github.io
# Start fetching contributors of neveragaindottech/neveragaindottech.github.io
# Start fetching contributors of neveragaindottech/neveragaindottech.github.io
# Start fetching contributors of realworldreact/realworldreact.com
# Start fetching contributors of jescalan/rupture
# Start fetching contributors of iansinnott/react-static-webpack-plugin
# Start fetching contributors of BerkeleyTrue/berkeleys-spectacle-boilerplate
# Start fetching contributors of carlsverre/react-outlet
# Start fetching contributors of chjj/marked
# Start fetching contributors of zachfitz/Ionic-Material
# Start fetching contributors of ReactTraining/react-router
# Start fetching contributors of ReactTraining/react-router
# Start fetching contributors of ReactTraining/react-router
# Start fetching contributors of react-native-community/react-native-linear-gradient
# Start fetching contributors of auth0-blog/falcor-create-demo
# Start fetching contributors of bahmutov/next-update
# Start fetching contributors of KyleAMathews/react-sparkline
# Start fetching contributors of google/web-starter-kit
# Start fetching contributors of airbnb/javascript
# Start fetching contributors of airbnb/javascript
# Start fetching contributors of airbnb/javascript
# Start fetching contributors of jekyll/jemoji
# Start fetching contributors of node-nock/nock
